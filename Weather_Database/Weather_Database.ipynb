# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.The citipy module finds the nearest city to 
# the latitude and longitude pair with a population of 500 or more.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import API key
from config import g_key
from config import weather_api_key
# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# First create teh basic URL for the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list. This creates the URL for each one and groups our records in sets of 50.
# enumerate can be used instead of creating to for loops
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Country": city_country,
                    "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | tadine
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | kayerkan
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | paracuru
# Processing Record 9 of Set 1 | matamoros
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | alberdi
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | hay river
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | saint-augustin
# Processing Record 21 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | kaka
# Processing Record 24 of Set 1 | chipinge
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | xining
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | ko samui
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | nizhneudinsk
# Processing Record 34 of Set 1 | ipixuna
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | maymanak
# City not found. Skipping...
# Processing Record 37 of Set 1 | husavik
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | inhambane
# Processing Record 42 of Set 1 | norfolk
# Processing Record 43 of Set 1 | hofn
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 1 | pahrump
# Processing Record 1 of Set 2 | bolshaya irba
# City not found. Skipping...
# Processing Record 2 of Set 2 | dwarka
# Processing Record 3 of Set 2 | zhoucun
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | inta
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | zhanaozen
# Processing Record 10 of Set 2 | srednekolymsk
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | chokwe
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | apiai
# Processing Record 15 of Set 2 | shenzhen
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | tshikapa
# Processing Record 18 of Set 2 | leningradskiy
# Processing Record 19 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 2 | vostok
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | naliya
# Processing Record 23 of Set 2 | micheweni
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | gumushane
# City not found. Skipping...
# Processing Record 26 of Set 2 | wiarton
# Processing Record 27 of Set 2 | tucurui
# Processing Record 28 of Set 2 | port-cartier
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | safaqis
# City not found. Skipping...
# Processing Record 33 of Set 2 | dongsheng
# Processing Record 34 of Set 2 | fairbanks
# Processing Record 35 of Set 2 | sangar
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | sulangan
# Processing Record 39 of Set 2 | kieta
# Processing Record 40 of Set 2 | san quintin
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | koungheul
# Processing Record 44 of Set 2 | serenje
# Processing Record 45 of Set 2 | sri aman
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | mount gambier
# Processing Record 49 of Set 2 | hanko
# Processing Record 50 of Set 2 | chyhyryn
# Processing Record 1 of Set 3 | berlevag
# Processing Record 2 of Set 3 | gander
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | nioki
# Processing Record 5 of Set 3 | batagay-alyta
# Processing Record 6 of Set 3 | grants
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | lalmohan
# Processing Record 10 of Set 3 | sinnamary
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | ponta do sol
# Processing Record 13 of Set 3 | delijan
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | farah
# Processing Record 16 of Set 3 | porteirinha
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | tak
# Processing Record 20 of Set 3 | cukai
# Processing Record 21 of Set 3 | lakes entrance
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | novyye burasy
# Processing Record 24 of Set 3 | puerto escondido
# Processing Record 25 of Set 3 | krapivinskiy
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | aklavik
# Processing Record 28 of Set 3 | alofi
# Processing Record 29 of Set 3 | zeya
# Processing Record 30 of Set 3 | atuona
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | praia da vitoria
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | christchurch
# Processing Record 35 of Set 3 | margate
# Processing Record 36 of Set 3 | sitka
# Processing Record 37 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 3 | chase
# Processing Record 39 of Set 3 | punta arenas
# Processing Record 40 of Set 3 | dunedin
# Processing Record 41 of Set 3 | oussouye
# Processing Record 42 of Set 3 | pemangkat
# Processing Record 43 of Set 3 | abnub
# Processing Record 44 of Set 3 | urengoy
# Processing Record 45 of Set 3 | khuzhir
# Processing Record 46 of Set 3 | tuatapere
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 3 | adre
# Processing Record 50 of Set 3 | barhi
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | kavaratti
# Processing Record 4 of Set 4 | virginia beach
# Processing Record 5 of Set 4 | pacific grove
# Processing Record 6 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | methven
# Processing Record 10 of Set 4 | sao joao da barra
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | sept-iles
# Processing Record 13 of Set 4 | yulara
# Processing Record 14 of Set 4 | itau de minas
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | hobyo
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | avarua
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | sancraieni
# Processing Record 22 of Set 4 | muncar
# Processing Record 23 of Set 4 | dingzhou
# Processing Record 24 of Set 4 | kruisfontein
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | arcata
# Processing Record 27 of Set 4 | talnakh
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | senno
# Processing Record 30 of Set 4 | ribeira grande
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | kirando
# Processing Record 33 of Set 4 | entebbe
# Processing Record 34 of Set 4 | hongjiang
# Processing Record 35 of Set 4 | marrakesh
# Processing Record 36 of Set 4 | lashio
# Processing Record 37 of Set 4 | jieshou
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | grindavik
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | champerico
# Processing Record 42 of Set 4 | mangaratiba
# Processing Record 43 of Set 4 | lisburn
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | itoman
# Processing Record 46 of Set 4 | ezhou
# Processing Record 47 of Set 4 | pandan
# Processing Record 48 of Set 4 | minot
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | aracaju
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | bella union
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | laguna
# Processing Record 8 of Set 5 | natchitoches
# Processing Record 9 of Set 5 | ketchikan
# Processing Record 10 of Set 5 | baruun-urt
# Processing Record 11 of Set 5 | awjilah
# Processing Record 12 of Set 5 | oranjemund
# Processing Record 13 of Set 5 | baykit
# Processing Record 14 of Set 5 | potam
# Processing Record 15 of Set 5 | sassandra
# Processing Record 16 of Set 5 | sidney
# Processing Record 17 of Set 5 | general pico
# Processing Record 18 of Set 5 | ovsyanka
# Processing Record 19 of Set 5 | nador
# Processing Record 20 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 5 | sidi ali
# Processing Record 22 of Set 5 | severo-yeniseyskiy
# Processing Record 23 of Set 5 | blairmore
# Processing Record 24 of Set 5 | te anau
# Processing Record 25 of Set 5 | castletown
# Processing Record 26 of Set 5 | mayo
# Processing Record 27 of Set 5 | denpasar
# Processing Record 28 of Set 5 | talara
# Processing Record 29 of Set 5 | awbari
# Processing Record 30 of Set 5 | gigmoto
# Processing Record 31 of Set 5 | lahij
# Processing Record 32 of Set 5 | muros
# Processing Record 33 of Set 5 | camacha
# Processing Record 34 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 5 | lakhnadon
# Processing Record 36 of Set 5 | mabaruma
# Processing Record 37 of Set 5 | canto do buriti
# Processing Record 38 of Set 5 | crewe
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | galle
# Processing Record 41 of Set 5 | cayenne
# Processing Record 42 of Set 5 | praia
# Processing Record 43 of Set 5 | turukhansk
# Processing Record 44 of Set 5 | capaccio
# Processing Record 45 of Set 5 | kirakira
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | norman wells
# Processing Record 49 of Set 5 | harper
# Processing Record 50 of Set 5 | kaohsiung
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | maceio
# Processing Record 3 of Set 6 | college
# Processing Record 4 of Set 6 | acapulco
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | anadyr
# Processing Record 8 of Set 6 | ampanihy
# Processing Record 9 of Set 6 | kungurtug
# Processing Record 10 of Set 6 | tugalan
# City not found. Skipping...
# Processing Record 11 of Set 6 | xuanhua
# Processing Record 12 of Set 6 | haskovo
# Processing Record 13 of Set 6 | vestmannaeyjar
# Processing Record 14 of Set 6 | belyy yar
# Processing Record 15 of Set 6 | parker
# Processing Record 16 of Set 6 | jishou
# Processing Record 17 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 18 of Set 6 | asosa
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | edgewater
# Processing Record 21 of Set 6 | istok
# Processing Record 22 of Set 6 | sheffield lake
# Processing Record 23 of Set 6 | uarini
# Processing Record 24 of Set 6 | zavallya
# Processing Record 25 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 6 | conceicao da barra
# Processing Record 27 of Set 6 | salvador
# Processing Record 28 of Set 6 | upernavik
# Processing Record 29 of Set 6 | pervomayskiy
# Processing Record 30 of Set 6 | san jeronimo
# Processing Record 31 of Set 6 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 6 | waddan
# Processing Record 33 of Set 6 | belem de sao francisco
# Processing Record 34 of Set 6 | marfino
# Processing Record 35 of Set 6 | provideniya
# Processing Record 36 of Set 6 | seymchan
# Processing Record 37 of Set 6 | taywarah
# Processing Record 38 of Set 6 | salgar
# Processing Record 39 of Set 6 | mondlo
# Processing Record 40 of Set 6 | fort nelson
# Processing Record 41 of Set 6 | wloszczowa
# Processing Record 42 of Set 6 | vangaindrano
# Processing Record 43 of Set 6 | benemerito de las americas
# Processing Record 44 of Set 6 | san miguel
# Processing Record 45 of Set 6 | beloha
# Processing Record 46 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 6 | tolaga bay
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | lavrentiya
# Processing Record 50 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | ust-kan
# Processing Record 2 of Set 7 | belmonte
# Processing Record 3 of Set 7 | orzhytsya
# Processing Record 4 of Set 7 | zvenigovo
# Processing Record 5 of Set 7 | cutzamala
# City not found. Skipping...
# Processing Record 6 of Set 7 | ivanovka
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | port hardy
# Processing Record 9 of Set 7 | shadrinsk
# Processing Record 10 of Set 7 | ixtapa
# Processing Record 11 of Set 7 | umtata
# Processing Record 12 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 14 of Set 7 | chilca
# Processing Record 15 of Set 7 | moose factory
# Processing Record 16 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 7 | shelburne
# Processing Record 18 of Set 7 | pochutla
# Processing Record 19 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 7 | zapolyarnyy
# Processing Record 21 of Set 7 | kupang
# Processing Record 22 of Set 7 | hami
# Processing Record 23 of Set 7 | adrar
# Processing Record 24 of Set 7 | rawson
# Processing Record 25 of Set 7 | yumen
# Processing Record 26 of Set 7 | mandiana
# Processing Record 27 of Set 7 | chak azam sahu
# Processing Record 28 of Set 7 | esperance
# Processing Record 29 of Set 7 | pedernales
# Processing Record 30 of Set 7 | codrington
# Processing Record 31 of Set 7 | launceston
# Processing Record 32 of Set 7 | atar
# Processing Record 33 of Set 7 | vaasa
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | varhaug
# Processing Record 36 of Set 7 | olga
# Processing Record 37 of Set 7 | sao miguel do araguaia
# Processing Record 38 of Set 7 | deep river
# Processing Record 39 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 7 | chokurdakh
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | sorland
# Processing Record 43 of Set 7 | nouadhibou
# Processing Record 44 of Set 7 | kota tinggi
# Processing Record 45 of Set 7 | lagunas
# Processing Record 46 of Set 7 | altay
# Processing Record 47 of Set 7 | ulaangom
# Processing Record 48 of Set 7 | saldanha
# Processing Record 49 of Set 7 | olinda
# Processing Record 50 of Set 7 | baghdad
# Processing Record 1 of Set 8 | bowen
# Processing Record 2 of Set 8 | road town
# Processing Record 3 of Set 8 | poum
# Processing Record 4 of Set 8 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 5 of Set 8 | moron
# Processing Record 6 of Set 8 | veraval
# Processing Record 7 of Set 8 | khash
# Processing Record 8 of Set 8 | flin flon
# Processing Record 9 of Set 8 | okha
# Processing Record 10 of Set 8 | kilakarai
# Processing Record 11 of Set 8 | bo rai
# Processing Record 12 of Set 8 | cockburn town
# Processing Record 13 of Set 8 | necochea
# Processing Record 14 of Set 8 | hirara
# Processing Record 15 of Set 8 | bintulu
# Processing Record 16 of Set 8 | ishigaki
# Processing Record 17 of Set 8 | chapais
# Processing Record 18 of Set 8 | alyangula
# Processing Record 19 of Set 8 | mayumba
# Processing Record 20 of Set 8 | sadovoye
# Processing Record 21 of Set 8 | monte cristi
# City not found. Skipping...
# Processing Record 22 of Set 8 | pavda
# City not found. Skipping...
# Processing Record 23 of Set 8 | oranjestad
# Processing Record 24 of Set 8 | cabedelo
# Processing Record 25 of Set 8 | ismailia
# Processing Record 26 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 27 of Set 8 | quatre cocos
# Processing Record 28 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 8 | buala
# Processing Record 30 of Set 8 | castro
# Processing Record 31 of Set 8 | alta
# Processing Record 32 of Set 8 | athens
# Processing Record 33 of Set 8 | sibolga
# Processing Record 34 of Set 8 | umm lajj
# Processing Record 35 of Set 8 | dudinka
# Processing Record 36 of Set 8 | broome
# Processing Record 37 of Set 8 | anchorage
# Processing Record 38 of Set 8 | meulaboh
# Processing Record 39 of Set 8 | oktyabrskiy
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | diamantino
# Processing Record 44 of Set 8 | makakilo city
# Processing Record 45 of Set 8 | palekh
# Processing Record 46 of Set 8 | okhotsk
# Processing Record 47 of Set 8 | fortuna
# Processing Record 48 of Set 8 | comodoro rivadavia
# Processing Record 49 of Set 8 | zmeinogorsk
# Processing Record 50 of Set 8 | salamiyah
# Processing Record 1 of Set 9 | rostovka
# Processing Record 2 of Set 9 | ugoofaaru
# Processing Record 3 of Set 9 | redmond
# Processing Record 4 of Set 9 | harwich
# Processing Record 5 of Set 9 | toora-khem
# Processing Record 6 of Set 9 | isilkul
# Processing Record 7 of Set 9 | shar
# Processing Record 8 of Set 9 | severo-kurilsk
# Processing Record 9 of Set 9 | bonthe
# Processing Record 10 of Set 9 | byron bay
# Processing Record 11 of Set 9 | kansk
# Processing Record 12 of Set 9 | portland
# Processing Record 13 of Set 9 | lagoa
# Processing Record 14 of Set 9 | griffin
# Processing Record 15 of Set 9 | severnyy
# Processing Record 16 of Set 9 | kars
# Processing Record 17 of Set 9 | auki
# Processing Record 18 of Set 9 | kanchanaburi
# Processing Record 19 of Set 9 | yangambi
# Processing Record 20 of Set 9 | ayagoz
# Processing Record 21 of Set 9 | pingliang
# Processing Record 22 of Set 9 | antofagasta
# Processing Record 23 of Set 9 | kysyl-syr
# Processing Record 24 of Set 9 | kashan
# Processing Record 25 of Set 9 | panaba
# Processing Record 26 of Set 9 | mayor pablo lagerenza
# Processing Record 27 of Set 9 | ternate
# Processing Record 28 of Set 9 | nantucket
# Processing Record 29 of Set 9 | amazar
# Processing Record 30 of Set 9 | rudbar
# Processing Record 31 of Set 9 | olafsvik
# Processing Record 32 of Set 9 | touba
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | kattivakkam
# Processing Record 35 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 36 of Set 9 | raudeberg
# Processing Record 37 of Set 9 | wahpeton
# Processing Record 38 of Set 9 | sandane
# Processing Record 39 of Set 9 | waipawa
# Processing Record 40 of Set 9 | mehamn
# Processing Record 41 of Set 9 | villa maria
# Processing Record 42 of Set 9 | antrim
# Processing Record 43 of Set 9 | penzance
# Processing Record 44 of Set 9 | aswan
# Processing Record 45 of Set 9 | channel-port aux basques
# Processing Record 46 of Set 9 | zheleznodorozhnyy
# Processing Record 47 of Set 9 | pitimbu
# Processing Record 48 of Set 9 | lana
# Processing Record 49 of Set 9 | darhan
# Processing Record 50 of Set 9 | harbour breton
# Processing Record 1 of Set 10 | mutoko
# Processing Record 2 of Set 10 | mogocha
# Processing Record 3 of Set 10 | elizabethtown
# Processing Record 4 of Set 10 | port shepstone
# Processing Record 5 of Set 10 | udachnyy
# Processing Record 6 of Set 10 | bathsheba
# Processing Record 7 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | vila franca do campo
# Processing Record 9 of Set 10 | elko
# Processing Record 10 of Set 10 | castro daire
# Processing Record 11 of Set 10 | puerto baquerizo moreno
# Processing Record 12 of Set 10 | aykhal
# Processing Record 13 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | alakurtti
# Processing Record 16 of Set 10 | ilhabela
# Processing Record 17 of Set 10 | sinegorye
# Processing Record 18 of Set 10 | kudahuvadhoo
# Processing Record 19 of Set 10 | port lincoln
# Processing Record 20 of Set 10 | cabo san lucas
# Processing Record 21 of Set 10 | tecoanapa
# Processing Record 22 of Set 10 | amapa
# Processing Record 23 of Set 10 | dvurechensk
# Processing Record 24 of Set 10 | nanortalik
# Processing Record 25 of Set 10 | las cruces
# Processing Record 26 of Set 10 | porto santo
# Processing Record 27 of Set 10 | mattru
# Processing Record 28 of Set 10 | akyab
# Processing Record 29 of Set 10 | ouadda
# Processing Record 30 of Set 10 | vao
# Processing Record 31 of Set 10 | remontnoye
# Processing Record 32 of Set 10 | hurghada
# Processing Record 33 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 10 | omagh
# Processing Record 35 of Set 10 | soyo
# Processing Record 36 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 10 | westport
# Processing Record 38 of Set 10 | manzil salim
# Processing Record 39 of Set 10 | santiago del estero
# Processing Record 40 of Set 10 | maragogi
# Processing Record 41 of Set 10 | amga
# Processing Record 42 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 10 | iracoubo
# Processing Record 44 of Set 10 | erenhot
# Processing Record 45 of Set 10 | alekseyevskaya
# Processing Record 46 of Set 10 | dawlatabad
# Processing Record 47 of Set 10 | plombieres
# Processing Record 48 of Set 10 | thousand oaks
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 11 | evansville
# Processing Record 2 of Set 11 | jiangyou
# Processing Record 3 of Set 11 | candawaga
# City not found. Skipping...
# Processing Record 4 of Set 11 | antibes
# Processing Record 5 of Set 11 | konya
# Processing Record 6 of Set 11 | jiuquan
# Processing Record 7 of Set 11 | palmer
# Processing Record 8 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 11 | chisec
# Processing Record 10 of Set 11 | emerald
# Processing Record 11 of Set 11 | bambous virieux
# Processing Record 12 of Set 11 | santa rosa
# Processing Record 13 of Set 11 | hailar
# Processing Record 14 of Set 11 | petatlan
# Processing Record 15 of Set 11 | port arthur
# Processing Record 16 of Set 11 | bealanana
# Processing Record 17 of Set 11 | wajir
# Processing Record 18 of Set 11 | ahipara
# Processing Record 19 of Set 11 | bayir
# Processing Record 20 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 11 | boralday
# Processing Record 22 of Set 11 | khasan
# Processing Record 23 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 11 | liverpool
# Processing Record 25 of Set 11 | antalaha
# Processing Record 26 of Set 11 | banff
# Processing Record 27 of Set 11 | innisfail
# Processing Record 28 of Set 11 | benguela
# Processing Record 29 of Set 11 | ulagan
# Processing Record 30 of Set 11 | simoes
# Processing Record 31 of Set 11 | ikirun
# Processing Record 32 of Set 11 | pimentel
# Processing Record 33 of Set 11 | burnie
# Processing Record 34 of Set 11 | tilichiki
# Processing Record 35 of Set 11 | huilong
# Processing Record 36 of Set 11 | povenets
# Processing Record 37 of Set 11 | dharchula
# Processing Record 38 of Set 11 | broken hill
# Processing Record 39 of Set 11 | tessalit
# Processing Record 40 of Set 11 | lagos
# Processing Record 41 of Set 11 | galbshtadt
# Processing Record 42 of Set 11 | atambua
# Processing Record 43 of Set 11 | caraballeda
# Processing Record 44 of Set 11 | polunochnoye
# Processing Record 45 of Set 11 | lazaro cardenas
# Processing Record 46 of Set 11 | pathein
# Processing Record 47 of Set 11 | mauguio
# Processing Record 48 of Set 11 | ust-kuyga
# Processing Record 49 of Set 11 | abha
# Processing Record 50 of Set 11 | morant bay
# Processing Record 1 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 12 | bocas del toro
# Processing Record 3 of Set 12 | miyoshi
# Processing Record 4 of Set 12 | del rio
# Processing Record 5 of Set 12 | nuuk
# Processing Record 6 of Set 12 | marystown
# Processing Record 7 of Set 12 | lingao
# Processing Record 8 of Set 12 | hailun
# Processing Record 9 of Set 12 | dhadar
# Processing Record 10 of Set 12 | kajaani
# Processing Record 11 of Set 12 | mastic beach
# Processing Record 12 of Set 12 | kushima
# Processing Record 13 of Set 12 | montlucon
# Processing Record 14 of Set 12 | narsaq
# Processing Record 15 of Set 12 | emporia
# Processing Record 16 of Set 12 | milas
# Processing Record 17 of Set 12 | warwick
# Processing Record 18 of Set 12 | talaja
# Processing Record 19 of Set 12 | tautira
# Processing Record 20 of Set 12 | aitape
# Processing Record 21 of Set 12 | dobrokoz
# Processing Record 22 of Set 12 | tiznit
# Processing Record 23 of Set 12 | lushunkou
# City not found. Skipping...
# Processing Record 24 of Set 12 | verbilki
# Processing Record 25 of Set 12 | visnes
# Processing Record 26 of Set 12 | sembe
# Processing Record 27 of Set 12 | suba
# Processing Record 28 of Set 12 | ucluelet
# Processing Record 29 of Set 12 | katobu
# Processing Record 30 of Set 12 | karema
# Processing Record 31 of Set 12 | balabac
# Processing Record 32 of Set 12 | balkhash
# Processing Record 33 of Set 12 | longjiang
# Processing Record 34 of Set 12 | alenquer
# Processing Record 35 of Set 12 | clyde river
# Processing Record 36 of Set 12 | singaparna
# Processing Record 37 of Set 12 | kerema
# Processing Record 38 of Set 12 | samarai
# Processing Record 39 of Set 12 | dryden
# Processing Record 40 of Set 12 | pedasi
# Processing Record 41 of Set 12 | hambantota
# Processing Record 42 of Set 12 | karratha
# Processing Record 43 of Set 12 | verkhnevilyuysk
# Processing Record 44 of Set 12 | mandalgovi
# Processing Record 45 of Set 12 | north bend
# Processing Record 46 of Set 12 | ihosy
# Processing Record 47 of Set 12 | harij
# Processing Record 48 of Set 12 | martapura
# Processing Record 49 of Set 12 | ostrovnoy
# Processing Record 50 of Set 12 | aksarayskiy
# Processing Record 1 of Set 13 | copiapo
# Processing Record 2 of Set 13 | dicabisagan
# Processing Record 3 of Set 13 | takoradi
# Processing Record 4 of Set 13 | mata
# Processing Record 5 of Set 13 | pozo colorado
# Processing Record 6 of Set 13 | hamilton
# Processing Record 7 of Set 13 | sal rei
# Processing Record 8 of Set 13 | hutang
# Processing Record 9 of Set 13 | abay
# Processing Record 10 of Set 13 | henties bay
# Processing Record 11 of Set 13 | stykkisholmur
# Processing Record 12 of Set 13 | havoysund
# Processing Record 13 of Set 13 | russell
# Processing Record 14 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 13 | yuci
# Processing Record 16 of Set 13 | sheksna
# Processing Record 17 of Set 13 | kuching
# Processing Record 18 of Set 13 | saint anthony
# Processing Record 19 of Set 13 | krasnoshchekovo
# Processing Record 20 of Set 13 | buraydah
# Processing Record 21 of Set 13 | sergeyevka
# Processing Record 22 of Set 13 | kaeo
# Processing Record 23 of Set 13 | blytheville
# Processing Record 24 of Set 13 | mahtomedi
# Processing Record 25 of Set 13 | san cristobal
# Processing Record 26 of Set 13 | buin
# Processing Record 27 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 28 of Set 13 | oistins
# Processing Record 29 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 13 | port keats
# Processing Record 31 of Set 13 | uk
# City not found. Skipping...
# Processing Record 32 of Set 13 | kutum
# Processing Record 33 of Set 13 | harlingen
# Processing Record 34 of Set 13 | ojinaga
# Processing Record 35 of Set 13 | teguise
# Processing Record 36 of Set 13 | asau
# Processing Record 37 of Set 13 | ulaanbaatar
# Processing Record 38 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 39 of Set 13 | chumikan
# Processing Record 40 of Set 13 | pitea
# Processing Record 41 of Set 13 | inirida
# Processing Record 42 of Set 13 | padang
# Processing Record 43 of Set 13 | sola
# Processing Record 44 of Set 13 | lilongwe
# Processing Record 45 of Set 13 | kloulklubed
# Processing Record 46 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 13 | port macquarie
# Processing Record 48 of Set 13 | ocampo
# Processing Record 49 of Set 13 | mporokoso
# Processing Record 50 of Set 13 | baza
# Processing Record 1 of Set 14 | maiduguri
# Processing Record 2 of Set 14 | dmitriyevka
# Processing Record 3 of Set 14 | waitati
# Processing Record 4 of Set 14 | seoul
# Processing Record 5 of Set 14 | narrabri
# Processing Record 6 of Set 14 | alta floresta
# Processing Record 7 of Set 14 | kenora
# Processing Record 8 of Set 14 | duku
# Processing Record 9 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 14 | lipin bor
# Processing Record 11 of Set 14 | pestyaki
# Processing Record 12 of Set 14 | salinas
# Processing Record 13 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 14 | bermejo
# Processing Record 15 of Set 14 | hervey bay
# Processing Record 16 of Set 14 | dickinson
# Processing Record 17 of Set 14 | sao jose da coroa grande
# Processing Record 18 of Set 14 | yinchuan
# Processing Record 19 of Set 14 | coos bay
# Processing Record 20 of Set 14 | almaznyy
# Processing Record 21 of Set 14 | tiarei
# Processing Record 22 of Set 14 | dubova
# Processing Record 23 of Set 14 | skibbereen
# Processing Record 24 of Set 14 | manyana
# Processing Record 25 of Set 14 | vilhena
# Processing Record 26 of Set 14 | parana
# Processing Record 27 of Set 14 | korla
# Processing Record 28 of Set 14 | saint-pierre
# Processing Record 29 of Set 14 | nelas
# Processing Record 30 of Set 14 | katherine
# Processing Record 31 of Set 14 | fuerte
# Processing Record 32 of Set 14 | brazzaville
# Processing Record 33 of Set 14 | kununurra
# Processing Record 34 of Set 14 | uchiza
# Processing Record 35 of Set 14 | ardmore
# Processing Record 36 of Set 14 | beian
# Processing Record 37 of Set 14 | male
# Processing Record 38 of Set 14 | leh
# Processing Record 39 of Set 14 | peace river
# Processing Record 40 of Set 14 | jevnaker
# Processing Record 41 of Set 14 | alepe
# Processing Record 42 of Set 14 | raymond
# Processing Record 43 of Set 14 | moranbah
# Processing Record 44 of Set 14 | deputatskiy
# Processing Record 45 of Set 14 | mongo
# Processing Record 46 of Set 14 | gawler
# Processing Record 47 of Set 14 | xai-xai
# Processing Record 48 of Set 14 | coahuayana
# Processing Record 49 of Set 14 | melenki
# Processing Record 50 of Set 14 | yerbogachen
# Processing Record 1 of Set 15 | san carlos
# Processing Record 2 of Set 15 | freeport
# Processing Record 3 of Set 15 | tura
# Processing Record 4 of Set 15 | south shields
# Processing Record 5 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 15 | qasigiannguit
# Processing Record 7 of Set 15 | calama
# Processing Record 8 of Set 15 | dehloran
# Processing Record 9 of Set 15 | bardiyah
# Processing Record 10 of Set 15 | algiers
# Processing Record 11 of Set 15 | sredec
# City not found. Skipping...
# Processing Record 12 of Set 15 | port moresby
# Processing Record 13 of Set 15 | tailai
# Processing Record 14 of Set 15 | vagur
# Processing Record 15 of Set 15 | dhidhdhoo
# Processing Record 16 of Set 15 | piacabucu
# Processing Record 17 of Set 15 | bokovskaya
# Processing Record 18 of Set 15 | wuxi
# Processing Record 19 of Set 15 | luwuk
# Processing Record 20 of Set 15 | vanimo
# Processing Record 21 of Set 15 | itigi
# Processing Record 22 of Set 15 | chengmai
# City not found. Skipping...
# Processing Record 23 of Set 15 | omsukchan
# Processing Record 24 of Set 15 | tezu
# Processing Record 25 of Set 15 | salalah
# Processing Record 26 of Set 15 | suluq
# Processing Record 27 of Set 15 | santa ana
# Processing Record 28 of Set 15 | barra da estiva
# Processing Record 29 of Set 15 | ures
# Processing Record 30 of Set 15 | santa isabel
# Processing Record 31 of Set 15 | klooga
# Processing Record 32 of Set 15 | san felipe
# Processing Record 33 of Set 15 | namikupa
# Processing Record 34 of Set 15 | kodinsk
# Processing Record 35 of Set 15 | ola
# Processing Record 36 of Set 15 | xochistlahuaca
# Processing Record 37 of Set 15 | tole
# Processing Record 38 of Set 15 | alice springs
# Processing Record 39 of Set 15 | mangrol
# Processing Record 40 of Set 15 | kurilsk
# Processing Record 41 of Set 15 | itagi
# Processing Record 42 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 15 | shimoda
# Processing Record 44 of Set 15 | karaton
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kaitangata -46.2817  169.8464     46.92        63         100
# 1        Tadine -21.5500  167.8833     67.66        75          83
# 2      Thompson  55.7435  -97.8558     69.89        37          97
# 3          Chuy -33.6971  -53.4616     55.29        82          61
# 4      Kayerkan  69.3497   87.7602     61.00        68          16
# 5  Puerto Ayora  -0.7393  -90.3518     80.56        77          17
# 6      Victoria  22.2855  114.1577     82.94        93         100
# 7      Paracuru  -3.4100  -39.0306     82.42        70          52
# 8     Matamoros  25.5333 -103.2500     86.11        46          75
# 9       Qaanaaq  77.4840  -69.3632     45.23        68          12
#
#    Wind Speed Country Current Description
# 0       10.58      NZ     overcast clouds
# 1        6.46      NC       broken clouds
# 2        7.14      CA     overcast clouds
# 3        6.82      UY       broken clouds
# 4        2.62      RU          few clouds
# 5        8.01      EC          few clouds
# 6        1.01      HK       moderate rain
# 7       14.09      BR       broken clouds
# 8        0.00      MX       broken clouds
# 9        2.73      GL          few clouds

# %%
# Change the column order
new_column_order  = ['City','Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kaitangata      NZ -46.2817  169.8464     46.92        63         100
# 1        Tadine      NC -21.5500  167.8833     67.66        75          83
# 2      Thompson      CA  55.7435  -97.8558     69.89        37          97
# 3          Chuy      UY -33.6971  -53.4616     55.29        82          61
# 4      Kayerkan      RU  69.3497   87.7602     61.00        68          16
# 5  Puerto Ayora      EC  -0.7393  -90.3518     80.56        77          17
# 6      Victoria      HK  22.2855  114.1577     82.94        93         100
# 7      Paracuru      BR  -3.4100  -39.0306     82.42        70          52
# 8     Matamoros      MX  25.5333 -103.2500     86.11        46          75
# 9       Qaanaaq      GL  77.4840  -69.3632     45.23        68          12
#
#    Wind Speed Current Description
# 0       10.58     overcast clouds
# 1        6.46       broken clouds
# 2        7.14     overcast clouds
# 3        6.82       broken clouds
# 4        2.62          few clouds
# 5        8.01          few clouds
# 6        1.01       moderate rain
# 7       14.09       broken clouds
# 8        0.00       broken clouds
# 9        2.73          few clouds

# %%
#Save dataframe as csv
pd.DataFrame.to_csv(city_data_df, 'WeatherPy_Database.csv',)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Kaitangata      NZ -46.2817  169.8464     46.92        63         100
# 1      Tadine      NC -21.5500  167.8833     67.66        75          83
# 2    Thompson      CA  55.7435  -97.8558     69.89        37          97
# 3        Chuy      UY -33.6971  -53.4616     55.29        82          61
# 4    Kayerkan      RU  69.3497   87.7602     61.00        68          16
#
#    Wind Speed Current Description
# 0       10.58     overcast clouds
# 1        6.46       broken clouds
# 2        7.14     overcast clouds
# 3        6.82       broken clouds
# 4        2.62          few clouds
