# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.The citipy module finds the nearest city to 
# the latitude and longitude pair with a population of 500 or more.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import API key
from config import g_key
from config import weather_api_key
# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# First create teh basic URL for the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list. This creates the URL for each one and groups our records in sets of 50.
# enumerate can be used instead of creating to for loops
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Country": city_country,
                    "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | savannah bight
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | victoria
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | airai
# Processing Record 13 of Set 1 | bogorodskoye
# Processing Record 14 of Set 1 | waddan
# Processing Record 15 of Set 1 | tefe
# Processing Record 16 of Set 1 | tripoli
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | biltine
# Processing Record 20 of Set 1 | bereznik
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | khandyga
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | lata
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | kahului
# Processing Record 28 of Set 1 | port macquarie
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | taltal
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | san patricio
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | acapulco
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | shache
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | yeniseysk
# Processing Record 40 of Set 1 | tabuk
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | sorland
# Processing Record 43 of Set 1 | port elizabeth
# Processing Record 44 of Set 1 | visby
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | hilo
# Processing Record 47 of Set 1 | sabang
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | leh
# Processing Record 2 of Set 2 | asau
# Processing Record 3 of Set 2 | tommot
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | ahipara
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | klyuchi
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | chake chake
# Processing Record 11 of Set 2 | naze
# Processing Record 12 of Set 2 | vanimo
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | vardo
# Processing Record 16 of Set 2 | narsaq
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | parkes
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | souillac
# Processing Record 22 of Set 2 | san policarpo
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | lompoc
# Processing Record 25 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 2 | moron
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | kloulklubed
# Processing Record 29 of Set 2 | celestun
# Processing Record 30 of Set 2 | kerema
# Processing Record 31 of Set 2 | lac du bonnet
# Processing Record 32 of Set 2 | waingapu
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | viedma
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | divnogorsk
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | tecoanapa
# Processing Record 41 of Set 2 | suraabad
# Processing Record 42 of Set 2 | dubbo
# Processing Record 43 of Set 2 | durazno
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | boguchany
# Processing Record 46 of Set 2 | yomou
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | snyder
# Processing Record 49 of Set 2 | burnie
# Processing Record 50 of Set 2 | pangai
# Processing Record 1 of Set 3 | sampit
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | cabedelo
# Processing Record 5 of Set 3 | bara
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | sharjah
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | touros
# Processing Record 11 of Set 3 | ergani
# Processing Record 12 of Set 3 | lukovetskiy
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | ndele
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | ahuimanu
# Processing Record 17 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 3 | cherskiy
# Processing Record 19 of Set 3 | dhaka
# Processing Record 20 of Set 3 | aklavik
# Processing Record 21 of Set 3 | shimoda
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | suhbaatar
# Processing Record 24 of Set 3 | poopo
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | arlit
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | saint-francois
# Processing Record 30 of Set 3 | dingle
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | gravelbourg
# Processing Record 33 of Set 3 | thinadhoo
# Processing Record 34 of Set 3 | korla
# Processing Record 35 of Set 3 | nanortalik
# Processing Record 36 of Set 3 | mount gambier
# Processing Record 37 of Set 3 | tazovskiy
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | yazman
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | sandpoint
# Processing Record 43 of Set 3 | boyolangu
# Processing Record 44 of Set 3 | am timan
# Processing Record 45 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 3 | kupino
# Processing Record 47 of Set 3 | almaznyy
# Processing Record 48 of Set 3 | nanticoke
# Processing Record 49 of Set 3 | baruun-urt
# Processing Record 50 of Set 3 | berdigestyakh
# Processing Record 1 of Set 4 | vostok
# Processing Record 2 of Set 4 | hong gai
# Processing Record 3 of Set 4 | puerto ayora
# Processing Record 4 of Set 4 | fare
# Processing Record 5 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 4 | labod
# Processing Record 7 of Set 4 | paamiut
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | beringovskiy
# Processing Record 11 of Set 4 | rio grande
# Processing Record 12 of Set 4 | portland
# Processing Record 13 of Set 4 | ribeira grande
# Processing Record 14 of Set 4 | mathbaria
# Processing Record 15 of Set 4 | udachnyy
# Processing Record 16 of Set 4 | neuruppin
# Processing Record 17 of Set 4 | rockport
# Processing Record 18 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 4 | te anau
# Processing Record 20 of Set 4 | coihaique
# Processing Record 21 of Set 4 | port hedland
# Processing Record 22 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 4 | ketchikan
# Processing Record 24 of Set 4 | berezovyy
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | havoysund
# Processing Record 27 of Set 4 | tiarei
# Processing Record 28 of Set 4 | dolinsk
# Processing Record 29 of Set 4 | lhokseumawe
# Processing Record 30 of Set 4 | adre
# Processing Record 31 of Set 4 | ca mau
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | cocal
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | sao joao da barra
# Processing Record 36 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 4 | komsomolskiy
# Processing Record 38 of Set 4 | buala
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | devonport
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | aswan
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | soyo
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | orsha
# Processing Record 50 of Set 4 | saint george
# Processing Record 1 of Set 5 | maarianhamina
# Processing Record 2 of Set 5 | kapuskasing
# Processing Record 3 of Set 5 | san felipe
# Processing Record 4 of Set 5 | obo
# Processing Record 5 of Set 5 | qaanaaq
# Processing Record 6 of Set 5 | remedios
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | korhogo
# Processing Record 9 of Set 5 | trincomalee
# Processing Record 10 of Set 5 | port hueneme
# Processing Record 11 of Set 5 | yar-sale
# Processing Record 12 of Set 5 | kutum
# Processing Record 13 of Set 5 | rantepao
# Processing Record 14 of Set 5 | waipawa
# Processing Record 15 of Set 5 | cheremukhovo
# Processing Record 16 of Set 5 | tukrah
# Processing Record 17 of Set 5 | chippewa falls
# Processing Record 18 of Set 5 | acari
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | warrnambool
# Processing Record 21 of Set 5 | panique
# Processing Record 22 of Set 5 | fairbanks
# Processing Record 23 of Set 5 | phuket
# Processing Record 24 of Set 5 | zeya
# Processing Record 25 of Set 5 | tornio
# Processing Record 26 of Set 5 | vila franca do campo
# Processing Record 27 of Set 5 | meadow lake
# Processing Record 28 of Set 5 | oistins
# Processing Record 29 of Set 5 | lixourion
# Processing Record 30 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 5 | maues
# Processing Record 32 of Set 5 | kyakhta
# Processing Record 33 of Set 5 | siruguppa
# Processing Record 34 of Set 5 | marystown
# Processing Record 35 of Set 5 | hithadhoo
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | furano
# Processing Record 38 of Set 5 | shamkhal
# Processing Record 39 of Set 5 | kesan
# Processing Record 40 of Set 5 | kathu
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | brae
# Processing Record 45 of Set 5 | balkanabat
# Processing Record 46 of Set 5 | villafranca de los barros
# Processing Record 47 of Set 5 | lazaro cardenas
# Processing Record 48 of Set 5 | maurawan
# Processing Record 49 of Set 5 | nuuk
# Processing Record 50 of Set 5 | aketi
# Processing Record 1 of Set 6 | situbondo
# Processing Record 2 of Set 6 | margate
# Processing Record 3 of Set 6 | bambanglipuro
# Processing Record 4 of Set 6 | flinders
# Processing Record 5 of Set 6 | shingu
# Processing Record 6 of Set 6 | usolye
# Processing Record 7 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 6 | ulladulla
# Processing Record 9 of Set 6 | henties bay
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | derzhavinsk
# Processing Record 12 of Set 6 | alofi
# Processing Record 13 of Set 6 | ouro fino
# Processing Record 14 of Set 6 | severo-kurilsk
# Processing Record 15 of Set 6 | concepcion del oro
# Processing Record 16 of Set 6 | rio claro
# Processing Record 17 of Set 6 | coxim
# Processing Record 18 of Set 6 | pankovka
# Processing Record 19 of Set 6 | atar
# Processing Record 20 of Set 6 | deputatskiy
# Processing Record 21 of Set 6 | lubao
# Processing Record 22 of Set 6 | mtambile
# Processing Record 23 of Set 6 | mackenzie
# Processing Record 24 of Set 6 | quirinopolis
# Processing Record 25 of Set 6 | huancavelica
# Processing Record 26 of Set 6 | manta
# Processing Record 27 of Set 6 | shenzhen
# Processing Record 28 of Set 6 | guerrero negro
# Processing Record 29 of Set 6 | tuktoyaktuk
# Processing Record 30 of Set 6 | alamos
# Processing Record 31 of Set 6 | san carlos
# Processing Record 32 of Set 6 | ayan
# Processing Record 33 of Set 6 | longyearbyen
# Processing Record 34 of Set 6 | tutoia
# Processing Record 35 of Set 6 | lima
# Processing Record 36 of Set 6 | cabo san lucas
# Processing Record 37 of Set 6 | teya
# Processing Record 38 of Set 6 | okhotsk
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | east london
# Processing Record 41 of Set 6 | beterou
# Processing Record 42 of Set 6 | key west
# Processing Record 43 of Set 6 | santa isabel do rio negro
# Processing Record 44 of Set 6 | nalut
# Processing Record 45 of Set 6 | walvis bay
# Processing Record 46 of Set 6 | port lincoln
# Processing Record 47 of Set 6 | ballina
# Processing Record 48 of Set 6 | ravar
# Processing Record 49 of Set 6 | kitimat
# Processing Record 50 of Set 6 | santa vitoria do palmar
# Processing Record 1 of Set 7 | lahaina
# Processing Record 2 of Set 7 | nishihara
# Processing Record 3 of Set 7 | severo-yeniseyskiy
# Processing Record 4 of Set 7 | balurghat
# Processing Record 5 of Set 7 | dawlatabad
# Processing Record 6 of Set 7 | perama
# Processing Record 7 of Set 7 | nikolskoye
# Processing Record 8 of Set 7 | markova
# Processing Record 9 of Set 7 | loreto
# Processing Record 10 of Set 7 | north bend
# Processing Record 11 of Set 7 | san antonio
# Processing Record 12 of Set 7 | chokurdakh
# Processing Record 13 of Set 7 | didwana
# Processing Record 14 of Set 7 | tambopata
# Processing Record 15 of Set 7 | progreso
# Processing Record 16 of Set 7 | guapiles
# Processing Record 17 of Set 7 | pointe-noire
# Processing Record 18 of Set 7 | lasa
# Processing Record 19 of Set 7 | parfenyevo
# Processing Record 20 of Set 7 | xai-xai
# Processing Record 21 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 7 | ilulissat
# Processing Record 23 of Set 7 | esperance
# Processing Record 24 of Set 7 | perbaungan
# Processing Record 25 of Set 7 | nouadhibou
# Processing Record 26 of Set 7 | kachug
# Processing Record 27 of Set 7 | omboue
# Processing Record 28 of Set 7 | nome
# Processing Record 29 of Set 7 | bintulu
# Processing Record 30 of Set 7 | darhan
# Processing Record 31 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 7 | high level
# Processing Record 33 of Set 7 | casa grande
# Processing Record 34 of Set 7 | khani
# Processing Record 35 of Set 7 | kununurra
# Processing Record 36 of Set 7 | egvekinot
# Processing Record 37 of Set 7 | jiaojiang
# Processing Record 38 of Set 7 | mahanoro
# Processing Record 39 of Set 7 | yarmouth
# Processing Record 40 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 7 | abashiri
# Processing Record 42 of Set 7 | kaspiysk
# Processing Record 43 of Set 7 | bolu
# Processing Record 44 of Set 7 | khotynets
# Processing Record 45 of Set 7 | belaya gora
# Processing Record 46 of Set 7 | richards bay
# Processing Record 47 of Set 7 | hare bay
# Processing Record 48 of Set 7 | buchanan
# Processing Record 49 of Set 7 | buraydah
# Processing Record 50 of Set 7 | nan
# Processing Record 1 of Set 8 | waitati
# Processing Record 2 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | karpathos
# Processing Record 6 of Set 8 | ozernovskiy
# Processing Record 7 of Set 8 | mutsu
# Processing Record 8 of Set 8 | itarema
# Processing Record 9 of Set 8 | lypnyazhka
# Processing Record 10 of Set 8 | verkhoyansk
# Processing Record 11 of Set 8 | palaikastron
# Processing Record 12 of Set 8 | veraval
# Processing Record 13 of Set 8 | bouafle
# Processing Record 14 of Set 8 | karratha
# Processing Record 15 of Set 8 | saint-georges
# Processing Record 16 of Set 8 | nizwa
# Processing Record 17 of Set 8 | ternate
# Processing Record 18 of Set 8 | sinnamary
# Processing Record 19 of Set 8 | areka
# Processing Record 20 of Set 8 | micheweni
# Processing Record 21 of Set 8 | pochutla
# Processing Record 22 of Set 8 | randolph
# Processing Record 23 of Set 8 | reguengos de monsaraz
# Processing Record 24 of Set 8 | krasnoselkup
# Processing Record 25 of Set 8 | berkovica
# Processing Record 26 of Set 8 | mayumba
# Processing Record 27 of Set 8 | logansport
# Processing Record 28 of Set 8 | ostersund
# Processing Record 29 of Set 8 | mukhen
# Processing Record 30 of Set 8 | porto santo
# Processing Record 31 of Set 8 | severomuysk
# Processing Record 32 of Set 8 | banda aceh
# Processing Record 33 of Set 8 | maunabo
# Processing Record 34 of Set 8 | sioux lookout
# Processing Record 35 of Set 8 | pandan
# Processing Record 36 of Set 8 | nebbi
# Processing Record 37 of Set 8 | curitibanos
# Processing Record 38 of Set 8 | edd
# Processing Record 39 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 8 | minnedosa
# Processing Record 41 of Set 8 | hakui
# Processing Record 42 of Set 8 | naryan-mar
# Processing Record 43 of Set 8 | faya
# Processing Record 44 of Set 8 | westport
# Processing Record 45 of Set 8 | omsukchan
# Processing Record 46 of Set 8 | camargo
# Processing Record 47 of Set 8 | tautira
# Processing Record 48 of Set 8 | tiksi
# Processing Record 49 of Set 8 | marzuq
# Processing Record 50 of Set 8 | banepa
# Processing Record 1 of Set 9 | strezhevoy
# Processing Record 2 of Set 9 | pundaguitan
# Processing Record 3 of Set 9 | nioro
# Processing Record 4 of Set 9 | saint-denis
# Processing Record 5 of Set 9 | the pas
# Processing Record 6 of Set 9 | lethem
# Processing Record 7 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 8 of Set 9 | aden
# Processing Record 9 of Set 9 | jiazi
# Processing Record 10 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 9 | khilok
# Processing Record 12 of Set 9 | hamilton
# Processing Record 13 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 14 of Set 9 | maniitsoq
# Processing Record 15 of Set 9 | merke
# Processing Record 16 of Set 9 | khomeynishahr
# City not found. Skipping...
# Processing Record 17 of Set 9 | kudahuvadhoo
# Processing Record 18 of Set 9 | kosh-agach
# Processing Record 19 of Set 9 | kerur
# Processing Record 20 of Set 9 | makakilo city
# Processing Record 21 of Set 9 | inta
# Processing Record 22 of Set 9 | pratapgarh
# Processing Record 23 of Set 9 | mnogovershinnyy
# Processing Record 24 of Set 9 | linguere
# Processing Record 25 of Set 9 | vallenar
# Processing Record 26 of Set 9 | nantucket
# Processing Record 27 of Set 9 | colimes
# Processing Record 28 of Set 9 | georgetown
# Processing Record 29 of Set 9 | bouca
# Processing Record 30 of Set 9 | springhill
# Processing Record 31 of Set 9 | lubu
# Processing Record 32 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 33 of Set 9 | hammerfest
# Processing Record 34 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 35 of Set 9 | cayenne
# Processing Record 36 of Set 9 | mlonggo
# Processing Record 37 of Set 9 | itacoatiara
# Processing Record 38 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 39 of Set 9 | ewa beach
# Processing Record 40 of Set 9 | himora
# City not found. Skipping...
# Processing Record 41 of Set 9 | kungurtug
# Processing Record 42 of Set 9 | neftegorsk
# Processing Record 43 of Set 9 | tallahassee
# Processing Record 44 of Set 9 | west fargo
# Processing Record 45 of Set 9 | popondetta
# Processing Record 46 of Set 9 | benguela
# Processing Record 47 of Set 9 | half moon bay
# Processing Record 48 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 9 | san luis
# Processing Record 50 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 10 | praia da vitoria
# Processing Record 2 of Set 10 | taoudenni
# Processing Record 3 of Set 10 | prince rupert
# Processing Record 4 of Set 10 | togur
# Processing Record 5 of Set 10 | palembang
# Processing Record 6 of Set 10 | charters towers
# Processing Record 7 of Set 10 | hofn
# Processing Record 8 of Set 10 | bilibino
# Processing Record 9 of Set 10 | ulan-ude
# Processing Record 10 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 10 | hollins
# Processing Record 12 of Set 10 | primero de marzo
# Processing Record 13 of Set 10 | evensk
# Processing Record 14 of Set 10 | conceicao do araguaia
# Processing Record 15 of Set 10 | leningradskiy
# Processing Record 16 of Set 10 | luderitz
# Processing Record 17 of Set 10 | pacific grove
# Processing Record 18 of Set 10 | kalabo
# Processing Record 19 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 10 | jiuquan
# Processing Record 21 of Set 10 | yarensk
# Processing Record 22 of Set 10 | stanislav
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | salinopolis
# Processing Record 25 of Set 10 | coquimbo
# Processing Record 26 of Set 10 | baykit
# Processing Record 27 of Set 10 | the valley
# Processing Record 28 of Set 10 | pompeu
# Processing Record 29 of Set 10 | san rafael
# Processing Record 30 of Set 10 | maridi
# Processing Record 31 of Set 10 | sistranda
# Processing Record 32 of Set 10 | hanmer springs
# Processing Record 33 of Set 10 | chifeng
# Processing Record 34 of Set 10 | merauke
# Processing Record 35 of Set 10 | iguape
# Processing Record 36 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 10 | bukama
# Processing Record 38 of Set 10 | usinsk
# Processing Record 39 of Set 10 | los llanos de aridane
# Processing Record 40 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 10 | yeppoon
# Processing Record 43 of Set 10 | turukhansk
# Processing Record 44 of Set 10 | hokitika
# Processing Record 45 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 10 | menongue
# Processing Record 47 of Set 10 | bozeman
# Processing Record 48 of Set 10 | kirakira
# Processing Record 49 of Set 10 | suntar
# Processing Record 50 of Set 10 | shcherbinka
# Processing Record 1 of Set 11 | nyurba
# Processing Record 2 of Set 11 | ostrovnoy
# Processing Record 3 of Set 11 | saint-pierre
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | bitung
# Processing Record 6 of Set 11 | hualmay
# Processing Record 7 of Set 11 | susuman
# Processing Record 8 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 11 | canmore
# Processing Record 10 of Set 11 | quelimane
# Processing Record 11 of Set 11 | miles city
# Processing Record 12 of Set 11 | poum
# Processing Record 13 of Set 11 | morant bay
# Processing Record 14 of Set 11 | paragominas
# Processing Record 15 of Set 11 | baclesu
# City not found. Skipping...
# Processing Record 16 of Set 11 | norilsk
# Processing Record 17 of Set 11 | port-gentil
# Processing Record 18 of Set 11 | aguada de pasajeros
# Processing Record 19 of Set 11 | cravo norte
# Processing Record 20 of Set 11 | kaprijke
# Processing Record 21 of Set 11 | vila velha
# Processing Record 22 of Set 11 | mana
# Processing Record 23 of Set 11 | tavda
# Processing Record 24 of Set 11 | brookings
# Processing Record 25 of Set 11 | usevya
# Processing Record 26 of Set 11 | lagos
# Processing Record 27 of Set 11 | sakakah
# Processing Record 28 of Set 11 | shanghai
# Processing Record 29 of Set 11 | itoman
# Processing Record 30 of Set 11 | pingzhuang
# Processing Record 31 of Set 11 | whitehorse
# Processing Record 32 of Set 11 | constitucion
# Processing Record 33 of Set 11 | sayyan
# Processing Record 34 of Set 11 | tainan
# Processing Record 35 of Set 11 | washougal
# Processing Record 36 of Set 11 | mantua
# Processing Record 37 of Set 11 | aksarka
# Processing Record 38 of Set 11 | tamara
# Processing Record 39 of Set 11 | ginir
# Processing Record 40 of Set 11 | kampot
# Processing Record 41 of Set 11 | honiara
# Processing Record 42 of Set 11 | laukaa
# Processing Record 43 of Set 11 | riohacha
# Processing Record 44 of Set 11 | evansville
# Processing Record 45 of Set 11 | lampa
# Processing Record 46 of Set 11 | pimentel
# Processing Record 47 of Set 11 | port hardy
# Processing Record 48 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 49 of Set 11 | wilkie
# Processing Record 50 of Set 11 | vanavara
# Processing Record 1 of Set 12 | klaksvik
# Processing Record 2 of Set 12 | yenangyaung
# Processing Record 3 of Set 12 | broken hill
# Processing Record 4 of Set 12 | katherine
# Processing Record 5 of Set 12 | bonavista
# Processing Record 6 of Set 12 | ziniare
# Processing Record 7 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 12 | meulaboh
# Processing Record 9 of Set 12 | kracheh
# City not found. Skipping...
# Processing Record 10 of Set 12 | sangar
# Processing Record 11 of Set 12 | strathmore
# Processing Record 12 of Set 12 | sovetskiy
# Processing Record 13 of Set 12 | uige
# Processing Record 14 of Set 12 | peace river
# Processing Record 15 of Set 12 | urumqi
# Processing Record 16 of Set 12 | general pico
# Processing Record 17 of Set 12 | sao jose da coroa grande
# Processing Record 18 of Set 12 | pipar
# Processing Record 19 of Set 12 | kulhudhuffushi
# Processing Record 20 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 21 of Set 12 | borogontsy
# Processing Record 22 of Set 12 | chicama
# Processing Record 23 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 24 of Set 12 | erie
# Processing Record 25 of Set 12 | cairns
# Processing Record 26 of Set 12 | goderich
# Processing Record 27 of Set 12 | el carmen
# Processing Record 28 of Set 12 | lichtenburg
# Processing Record 29 of Set 12 | xingcheng
# Processing Record 30 of Set 12 | tomatlan
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | lamar
# Processing Record 33 of Set 12 | tura
# Processing Record 34 of Set 12 | san lorenzo
# Processing Record 35 of Set 12 | yuxia
# Processing Record 36 of Set 12 | sattenapalle
# Processing Record 37 of Set 12 | kawalu
# Processing Record 38 of Set 12 | thunder bay
# Processing Record 39 of Set 12 | hasaki
# Processing Record 40 of Set 12 | galion
# Processing Record 41 of Set 12 | kieta
# Processing Record 42 of Set 12 | cidreira
# Processing Record 43 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 12 | deniliquin
# Processing Record 45 of Set 12 | araouane
# Processing Record 46 of Set 12 | sibolga
# Processing Record 47 of Set 12 | pala
# Processing Record 48 of Set 12 | leland
# Processing Record 49 of Set 12 | batemans bay
# Processing Record 50 of Set 12 | gimli
# Processing Record 1 of Set 13 | talnakh
# Processing Record 2 of Set 13 | lakhdenpokhya
# Processing Record 3 of Set 13 | portalegre
# Processing Record 4 of Set 13 | grindavik
# Processing Record 5 of Set 13 | bosaso
# Processing Record 6 of Set 13 | nyakahanga
# Processing Record 7 of Set 13 | kangaba
# Processing Record 8 of Set 13 | byron bay
# Processing Record 9 of Set 13 | sindand
# City not found. Skipping...
# Processing Record 10 of Set 13 | vazhiny
# Processing Record 11 of Set 13 | yerbogachen
# Processing Record 12 of Set 13 | vestmannaeyjar
# Processing Record 13 of Set 13 | simplicio mendes
# Processing Record 14 of Set 13 | tigil
# Processing Record 15 of Set 13 | kichera
# Processing Record 16 of Set 13 | aksaray
# Processing Record 17 of Set 13 | pangnirtung
# Processing Record 18 of Set 13 | manhattan
# Processing Record 19 of Set 13 | mandera
# Processing Record 20 of Set 13 | kumluca
# Processing Record 21 of Set 13 | jaguarari
# Processing Record 22 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | fereydun kenar
# Processing Record 24 of Set 13 | grants
# Processing Record 25 of Set 13 | jalu
# Processing Record 26 of Set 13 | nelson bay
# Processing Record 27 of Set 13 | ponta delgada
# Processing Record 28 of Set 13 | champerico
# Processing Record 29 of Set 13 | morgan city
# Processing Record 30 of Set 13 | antofagasta
# Processing Record 31 of Set 13 | olkusz
# Processing Record 32 of Set 13 | catamarca
# Processing Record 33 of Set 13 | samborondon
# Processing Record 34 of Set 13 | san ramon
# Processing Record 35 of Set 13 | san andres
# Processing Record 36 of Set 13 | akdepe
# Processing Record 37 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 13 | mogok
# Processing Record 39 of Set 13 | hami
# Processing Record 40 of Set 13 | caravelas
# Processing Record 41 of Set 13 | shakawe
# Processing Record 42 of Set 13 | nisia floresta
# Processing Record 43 of Set 13 | moose factory
# Processing Record 44 of Set 13 | kenitra
# Processing Record 45 of Set 13 | ust-nera
# Processing Record 46 of Set 13 | daru
# Processing Record 47 of Set 13 | roma
# Processing Record 48 of Set 13 | porto novo
# Processing Record 49 of Set 13 | plettenberg bay
# Processing Record 50 of Set 13 | ajdabiya
# Processing Record 1 of Set 14 | padang
# Processing Record 2 of Set 14 | mersing
# Processing Record 3 of Set 14 | sulphur
# Processing Record 4 of Set 14 | tateyama
# Processing Record 5 of Set 14 | verkh-chebula
# Processing Record 6 of Set 14 | rorvik
# Processing Record 7 of Set 14 | escanaba
# Processing Record 8 of Set 14 | damietta
# Processing Record 9 of Set 14 | tilichiki
# Processing Record 10 of Set 14 | sainte-marie
# Processing Record 11 of Set 14 | port augusta
# Processing Record 12 of Set 14 | saint-augustin
# Processing Record 13 of Set 14 | chor
# Processing Record 14 of Set 14 | kopyevo
# City not found. Skipping...
# Processing Record 15 of Set 14 | medvedka
# Processing Record 16 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 18 of Set 14 | jiquilisco
# Processing Record 19 of Set 14 | pannonhalma
# Processing Record 20 of Set 14 | henderson
# Processing Record 21 of Set 14 | adrar
# Processing Record 22 of Set 14 | sur
# Processing Record 23 of Set 14 | saint anthony
# Processing Record 24 of Set 14 | zyryanka
# Processing Record 25 of Set 14 | orumiyeh
# Processing Record 26 of Set 14 | rawson
# Processing Record 27 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 28 of Set 14 | ercis
# Processing Record 29 of Set 14 | isangel
# Processing Record 30 of Set 14 | marienburg
# Processing Record 31 of Set 14 | chernyshevskiy
# Processing Record 32 of Set 14 | whitley bay
# Processing Record 33 of Set 14 | kalmunai
# Processing Record 34 of Set 14 | yambio
# Processing Record 35 of Set 14 | beloha
# Processing Record 36 of Set 14 | sahuaripa
# Processing Record 37 of Set 14 | abu dhabi
# Processing Record 38 of Set 14 | qasigiannguit
# Processing Record 39 of Set 14 | porto recanati
# Processing Record 40 of Set 14 | parvatsar
# Processing Record 41 of Set 14 | mildura
# Processing Record 42 of Set 14 | shubarshi
# Processing Record 43 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 14 | muros
# Processing Record 45 of Set 14 | lahad datu
# Processing Record 46 of Set 14 | yerkoy
# Processing Record 47 of Set 14 | matamoros
# Processing Record 48 of Set 14 | marawi
# Processing Record 49 of Set 14 | abriaqui
# Processing Record 50 of Set 14 | igarka
# Processing Record 1 of Set 15 | imbituba
# Processing Record 2 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 3 of Set 15 | kaeo
# Processing Record 4 of Set 15 | tiznit
# Processing Record 5 of Set 15 | termiz
# Processing Record 6 of Set 15 | talcahuano
# Processing Record 7 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 8 of Set 15 | malmesbury
# Processing Record 9 of Set 15 | abaete
# Processing Record 10 of Set 15 | notre-dame-du-lac
# Processing Record 11 of Set 15 | podgorica
# Processing Record 12 of Set 15 | maceio
# Processing Record 13 of Set 15 | havre-saint-pierre
# Processing Record 14 of Set 15 | tual
# Processing Record 15 of Set 15 | comodoro rivadavia
# Processing Record 16 of Set 15 | gigmoto
# Processing Record 17 of Set 15 | ulaanbaatar
# Processing Record 18 of Set 15 | altay
# Processing Record 19 of Set 15 | yulara
# Processing Record 20 of Set 15 | hanna
# Processing Record 21 of Set 15 | punta alta
# Processing Record 22 of Set 15 | gouyave
# Processing Record 23 of Set 15 | pokhara
# Processing Record 24 of Set 15 | sambava
# Processing Record 25 of Set 15 | beira
# Processing Record 26 of Set 15 | salym
# Processing Record 27 of Set 15 | nagykoros
# Processing Record 28 of Set 15 | muisne
# Processing Record 29 of Set 15 | yumen
# Processing Record 30 of Set 15 | peterhead
# Processing Record 31 of Set 15 | koluszki
# Processing Record 32 of Set 15 | la asuncion
# Processing Record 33 of Set 15 | paita
# Processing Record 34 of Set 15 | malinovoye ozero
# Processing Record 35 of Set 15 | sola
# Processing Record 36 of Set 15 | puranpur
# Processing Record 37 of Set 15 | chumikan
# Processing Record 38 of Set 15 | kavaratti
# Processing Record 39 of Set 15 | lieksa
# Processing Record 40 of Set 15 | zhezkazgan
# Processing Record 41 of Set 15 | mayo
# Processing Record 42 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 15 | jaleswar
# Processing Record 44 of Set 15 | salinas
# Processing Record 45 of Set 15 | hambantota
# Processing Record 46 of Set 15 | keuruu
# Processing Record 47 of Set 15 | srednekolymsk
# Processing Record 48 of Set 15 | orange walk
# Processing Record 49 of Set 15 | port hawkesbury
# Processing Record 50 of Set 15 | atambua
# Processing Record 1 of Set 16 | mankono
# Processing Record 2 of Set 16 | road town
# Processing Record 3 of Set 16 | benghazi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura -46.1927  168.8643     34.48        99          99
# 1  Savannah Bight  16.4500  -85.8500     89.65        79         100
# 2          Albany  42.6001  -73.9662     88.14        60          17
# 3        Victoria  22.2855  114.1577     85.32        92         100
# 4          Hobart -42.8794  147.3294     44.46        87          12
# 5        Katsuura  35.1333  140.3000     84.31        89         100
# 6         Ushuaia -54.8000  -68.3000     42.46        61          40
# 7    Punta Arenas -53.1500  -70.9167     42.91        70          75
# 8        Bengkulu  -3.8004  102.2655     76.55        91          62
# 9       Saskylakh  71.9167  114.0833     60.19        56          87
#
#    Wind Speed Country Current Description
# 0        3.83      NZ     overcast clouds
# 1       19.71      HN     overcast clouds
# 2        3.71      US          few clouds
# 3        1.01      HK          light rain
# 4        4.00      AU          few clouds
# 5       24.09      JP     overcast clouds
# 6        6.91      AR    scattered clouds
# 7       18.41      CL       broken clouds
# 8        4.52      ID       broken clouds
# 9        8.08      RU     overcast clouds

# %%
# Change the column order
new_column_order  = ['City','Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     34.48        99          99
# 1  Savannah Bight      HN  16.4500  -85.8500     89.65        79         100
# 2          Albany      US  42.6001  -73.9662     88.14        60          17
# 3        Victoria      HK  22.2855  114.1577     85.32        92         100
# 4          Hobart      AU -42.8794  147.3294     44.46        87          12
# 5        Katsuura      JP  35.1333  140.3000     84.31        89         100
# 6         Ushuaia      AR -54.8000  -68.3000     42.46        61          40
# 7    Punta Arenas      CL -53.1500  -70.9167     42.91        70          75
# 8        Bengkulu      ID  -3.8004  102.2655     76.55        91          62
# 9       Saskylakh      RU  71.9167  114.0833     60.19        56          87
#
#    Wind Speed Current Description
# 0        3.83     overcast clouds
# 1       19.71     overcast clouds
# 2        3.71          few clouds
# 3        1.01          light rain
# 4        4.00          few clouds
# 5       24.09     overcast clouds
# 6        6.91    scattered clouds
# 7       18.41       broken clouds
# 8        4.52       broken clouds
# 9        8.08     overcast clouds

# %%
#Save dataframe as csv
pd.DataFrame.to_csv(city_data_df, 'WeatherPy_Database.csv', index_label='City_ID')
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     34.48        99          99
# 1  Savannah Bight      HN  16.4500  -85.8500     89.65        79         100
# 2          Albany      US  42.6001  -73.9662     88.14        60          17
# 3        Victoria      HK  22.2855  114.1577     85.32        92         100
# 4          Hobart      AU -42.8794  147.3294     44.46        87          12
#
#    Wind Speed Current Description
# 0        3.83     overcast clouds
# 1       19.71     overcast clouds
# 2        3.71          few clouds
# 3        1.01          light rain
# 4        4.00          few clouds
