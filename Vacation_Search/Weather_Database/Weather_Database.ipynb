# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
import requests

# Use the citipy module to determine city based on latitude and longitude.The citipy module finds the nearest city to 
# the latitude and longitude pair with a population of 500 or more.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import API key
from config import g_key
from config import weather_api_key
# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# First create teh basic URL for the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list. This creates the URL for each one and groups our records in sets of 50.
# enumerate can be used instead of creating to for loops
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                    "Lat": city_lat,
                    "Lng": city_lng,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Country": city_country,
                    "Current Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | auki
# Processing Record 4 of Set 1 | sambava
# Processing Record 5 of Set 1 | namwala
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | cayenne
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | bayan
# Processing Record 12 of Set 1 | bengkulu
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | lorengau
# Processing Record 16 of Set 1 | kandava
# Processing Record 17 of Set 1 | kruisfontein
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | grand gaube
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | okhotsk
# Processing Record 24 of Set 1 | ayer tawar
# Processing Record 25 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | emerald
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | mahebourg
# Processing Record 32 of Set 1 | san cristobal
# Processing Record 33 of Set 1 | gorno-altaysk
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | dunmore east
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | grimma
# Processing Record 41 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | skiros
# City not found. Skipping...
# Processing Record 46 of Set 1 | tsogni
# Processing Record 47 of Set 1 | seoul
# Processing Record 48 of Set 1 | kailua
# Processing Record 49 of Set 1 | zaysan
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | port hardy
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | cockburn town
# Processing Record 5 of Set 2 | arman
# Processing Record 6 of Set 2 | mount isa
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 2 | talnakh
# Processing Record 12 of Set 2 | batticaloa
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | umarkot
# Processing Record 15 of Set 2 | lovington
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | mareeba
# Processing Record 21 of Set 2 | taunggyi
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | muros
# Processing Record 24 of Set 2 | coahuayana
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | ushumun
# Processing Record 28 of Set 2 | pundaguitan
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | kamenka
# Processing Record 31 of Set 2 | meadow lake
# Processing Record 32 of Set 2 | broome
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | padang
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | presidencia roque saenz pena
# Processing Record 38 of Set 2 | atasu
# Processing Record 39 of Set 2 | oranjemund
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | rancho palos verdes
# Processing Record 42 of Set 2 | korla
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 2 | verkhnevilyuysk
# Processing Record 46 of Set 2 | aksay
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | rafaela
# Processing Record 49 of Set 2 | longyearbyen
# Processing Record 50 of Set 2 | amahai
# Processing Record 1 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | qaqortoq
# Processing Record 4 of Set 3 | huanren
# Processing Record 5 of Set 3 | taoudenni
# Processing Record 6 of Set 3 | yuancheng
# Processing Record 7 of Set 3 | sao filipe
# Processing Record 8 of Set 3 | cody
# Processing Record 9 of Set 3 | praia da vitoria
# Processing Record 10 of Set 3 | calolziocorte
# Processing Record 11 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 3 | bandarbeyla
# Processing Record 16 of Set 3 | jimma
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | acarau
# Processing Record 19 of Set 3 | maceio
# Processing Record 20 of Set 3 | pochinki
# Processing Record 21 of Set 3 | dafeng
# Processing Record 22 of Set 3 | marana
# Processing Record 23 of Set 3 | musoma
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | havre-saint-pierre
# Processing Record 28 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 3 | touros
# Processing Record 30 of Set 3 | lieksa
# Processing Record 31 of Set 3 | qaanaaq
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | walvis bay
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | caraballeda
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | portland
# Processing Record 38 of Set 3 | victor harbor
# Processing Record 39 of Set 3 | mitu
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | yulara
# Processing Record 42 of Set 3 | binzhou
# Processing Record 43 of Set 3 | kaeo
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | liwan
# Processing Record 46 of Set 3 | faya
# Processing Record 47 of Set 3 | ostrovnoy
# Processing Record 48 of Set 3 | zitiste
# Processing Record 49 of Set 3 | mansehra
# Processing Record 50 of Set 3 | byron bay
# Processing Record 1 of Set 4 | mormugao
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | ashqelon
# Processing Record 4 of Set 4 | baykit
# Processing Record 5 of Set 4 | murgab
# Processing Record 6 of Set 4 | valky
# Processing Record 7 of Set 4 | guanambi
# Processing Record 8 of Set 4 | ceuta
# Processing Record 9 of Set 4 | honiara
# Processing Record 10 of Set 4 | hobyo
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | tucurui
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | olinda
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | tasiilaq
# Processing Record 19 of Set 4 | tamandare
# Processing Record 20 of Set 4 | totskoye
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | diamantino
# Processing Record 24 of Set 4 | puerto ayora
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | ketchikan
# Processing Record 27 of Set 4 | isangel
# Processing Record 28 of Set 4 | belaya gora
# Processing Record 29 of Set 4 | vysokogornyy
# Processing Record 30 of Set 4 | alindao
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | kirakira
# Processing Record 35 of Set 4 | antananarivo
# Processing Record 36 of Set 4 | bubaque
# Processing Record 37 of Set 4 | arys
# Processing Record 38 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 4 | coquimbo
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | obanazawa
# Processing Record 42 of Set 4 | xuddur
# Processing Record 43 of Set 4 | pomuch
# Processing Record 44 of Set 4 | gwanda
# Processing Record 45 of Set 4 | nacala
# Processing Record 46 of Set 4 | jiuquan
# Processing Record 47 of Set 4 | arraial do cabo
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | oschersleben
# Processing Record 50 of Set 4 | makasar
# Processing Record 1 of Set 5 | bac lieu
# Processing Record 2 of Set 5 | concordia
# Processing Record 3 of Set 5 | dikson
# Processing Record 4 of Set 5 | kisesa
# Processing Record 5 of Set 5 | alamogordo
# Processing Record 6 of Set 5 | ouallam
# Processing Record 7 of Set 5 | coihueco
# Processing Record 8 of Set 5 | preobrazheniye
# Processing Record 9 of Set 5 | neuquen
# Processing Record 10 of Set 5 | craig
# Processing Record 11 of Set 5 | sioux lookout
# Processing Record 12 of Set 5 | sorong
# Processing Record 13 of Set 5 | kemijarvi
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | masyaf
# Processing Record 16 of Set 5 | lithakia
# Processing Record 17 of Set 5 | mazamari
# Processing Record 18 of Set 5 | te anau
# Processing Record 19 of Set 5 | bajil
# Processing Record 20 of Set 5 | siddipet
# Processing Record 21 of Set 5 | korem
# Processing Record 22 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | bom jesus
# Processing Record 25 of Set 5 | ashtabula
# Processing Record 26 of Set 5 | san patricio
# Processing Record 27 of Set 5 | akureyri
# Processing Record 28 of Set 5 | igarka
# Processing Record 29 of Set 5 | palmas
# Processing Record 30 of Set 5 | rincon
# Processing Record 31 of Set 5 | ahuimanu
# Processing Record 32 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | port elizabeth
# Processing Record 34 of Set 5 | caxito
# Processing Record 35 of Set 5 | abnub
# Processing Record 36 of Set 5 | zhezkazgan
# Processing Record 37 of Set 5 | bardiyah
# Processing Record 38 of Set 5 | san nicolas
# Processing Record 39 of Set 5 | alugan
# Processing Record 40 of Set 5 | hirara
# Processing Record 41 of Set 5 | kodinsk
# Processing Record 42 of Set 5 | sompeta
# Processing Record 43 of Set 5 | ayan
# Processing Record 44 of Set 5 | port-gentil
# Processing Record 45 of Set 5 | manzil jamil
# City not found. Skipping...
# Processing Record 46 of Set 5 | hervey bay
# Processing Record 47 of Set 5 | kupang
# Processing Record 48 of Set 5 | ipira
# Processing Record 49 of Set 5 | iquique
# Processing Record 50 of Set 5 | zaragoza
# Processing Record 1 of Set 6 | matara
# Processing Record 2 of Set 6 | kijang
# Processing Record 3 of Set 6 | sansai
# City not found. Skipping...
# Processing Record 4 of Set 6 | saint-joseph
# Processing Record 5 of Set 6 | northam
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | ginda
# Processing Record 8 of Set 6 | sangar
# Processing Record 9 of Set 6 | krasnoselkup
# Processing Record 10 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 6 | tual
# Processing Record 12 of Set 6 | nioro
# Processing Record 13 of Set 6 | fare
# Processing Record 14 of Set 6 | faanui
# Processing Record 15 of Set 6 | abha
# Processing Record 16 of Set 6 | hami
# Processing Record 17 of Set 6 | hilton head island
# Processing Record 18 of Set 6 | damietta
# Processing Record 19 of Set 6 | ngaoundere
# Processing Record 20 of Set 6 | margate
# Processing Record 21 of Set 6 | sisimiut
# Processing Record 22 of Set 6 | souillac
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | san quintin
# Processing Record 25 of Set 6 | chokurdakh
# Processing Record 26 of Set 6 | hovd
# Processing Record 27 of Set 6 | westport
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | merrill
# Processing Record 30 of Set 6 | shimoda
# Processing Record 31 of Set 6 | leshukonskoye
# Processing Record 32 of Set 6 | keti bandar
# Processing Record 33 of Set 6 | antofagasta
# Processing Record 34 of Set 6 | provost
# Processing Record 35 of Set 6 | dharchula
# Processing Record 36 of Set 6 | dunedin
# Processing Record 37 of Set 6 | juegang
# Processing Record 38 of Set 6 | huarmey
# Processing Record 39 of Set 6 | freeport
# Processing Record 40 of Set 6 | avera
# Processing Record 41 of Set 6 | yabrud
# Processing Record 42 of Set 6 | rexburg
# Processing Record 43 of Set 6 | pekalongan
# Processing Record 44 of Set 6 | saint george
# Processing Record 45 of Set 6 | hun
# Processing Record 46 of Set 6 | severo-kurilsk
# Processing Record 47 of Set 6 | kaihua
# Processing Record 48 of Set 6 | wawa
# Processing Record 49 of Set 6 | thompson
# Processing Record 50 of Set 6 | mount gambier
# Processing Record 1 of Set 7 | ahipara
# Processing Record 2 of Set 7 | mecca
# Processing Record 3 of Set 7 | tiksi
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | kirishi
# Processing Record 6 of Set 7 | codajas
# Processing Record 7 of Set 7 | ayagoz
# Processing Record 8 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 7 | bairiki
# Processing Record 10 of Set 7 | genhe
# Processing Record 11 of Set 7 | zmievka
# City not found. Skipping...
# Processing Record 12 of Set 7 | hithadhoo
# Processing Record 13 of Set 7 | yagodnoye
# Processing Record 14 of Set 7 | neyshabur
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | rio gallegos
# Processing Record 17 of Set 7 | lebu
# Processing Record 18 of Set 7 | puerto maldonado
# Processing Record 19 of Set 7 | tapejara
# Processing Record 20 of Set 7 | kidal
# Processing Record 21 of Set 7 | rajula
# Processing Record 22 of Set 7 | saquarema
# Processing Record 23 of Set 7 | panjab
# Processing Record 24 of Set 7 | siemiatycze
# Processing Record 25 of Set 7 | bijie
# Processing Record 26 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | saint-georges
# Processing Record 29 of Set 7 | takoradi
# Processing Record 30 of Set 7 | canmore
# Processing Record 31 of Set 7 | asau
# Processing Record 32 of Set 7 | pisco
# Processing Record 33 of Set 7 | sao miguel do araguaia
# Processing Record 34 of Set 7 | kisangani
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 7 | acapulco
# Processing Record 38 of Set 7 | chissamba
# Processing Record 39 of Set 7 | cananea
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | alice springs
# Processing Record 42 of Set 7 | ratangarh
# Processing Record 43 of Set 7 | hargeysa
# Processing Record 44 of Set 7 | ola
# Processing Record 45 of Set 7 | paredon
# Processing Record 46 of Set 7 | asfi
# Processing Record 47 of Set 7 | darhan
# Processing Record 48 of Set 7 | maralal
# Processing Record 49 of Set 7 | alto araguaia
# Processing Record 50 of Set 7 | tete
# Processing Record 1 of Set 8 | flin flon
# Processing Record 2 of Set 8 | san miguel de cauri
# Processing Record 3 of Set 8 | bongandanga
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | wakkanai
# Processing Record 6 of Set 8 | gornyak
# Processing Record 7 of Set 8 | perm
# Processing Record 8 of Set 8 | shelburne
# Processing Record 9 of Set 8 | dauphin
# Processing Record 10 of Set 8 | inyonga
# Processing Record 11 of Set 8 | olafsvik
# Processing Record 12 of Set 8 | honningsvag
# Processing Record 13 of Set 8 | sheregesh
# Processing Record 14 of Set 8 | gravdal
# Processing Record 15 of Set 8 | aswan
# Processing Record 16 of Set 8 | sistranda
# Processing Record 17 of Set 8 | zlobin
# Processing Record 18 of Set 8 | bafoulabe
# Processing Record 19 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 8 | arkhangelsk
# Processing Record 21 of Set 8 | zapresic
# Processing Record 22 of Set 8 | umm lajj
# Processing Record 23 of Set 8 | los llanos de aridane
# Processing Record 24 of Set 8 | san juan nepomuceno
# Processing Record 25 of Set 8 | elizabeth city
# Processing Record 26 of Set 8 | carlyle
# Processing Record 27 of Set 8 | horsham
# Processing Record 28 of Set 8 | likasi
# Processing Record 29 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 8 | quatre cocos
# Processing Record 31 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 8 | wabash
# Processing Record 33 of Set 8 | kahului
# Processing Record 34 of Set 8 | key west
# Processing Record 35 of Set 8 | chengkung
# City not found. Skipping...
# Processing Record 36 of Set 8 | hluti
# Processing Record 37 of Set 8 | ongwediva
# Processing Record 38 of Set 8 | teya
# Processing Record 39 of Set 8 | montepuez
# Processing Record 40 of Set 8 | plainview
# Processing Record 41 of Set 8 | necochea
# Processing Record 42 of Set 8 | lasa
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 8 | sao felix do xingu
# Processing Record 46 of Set 8 | edd
# Processing Record 47 of Set 8 | hasaki
# Processing Record 48 of Set 8 | college
# Processing Record 49 of Set 8 | xining
# Processing Record 50 of Set 8 | makakilo city
# Processing Record 1 of Set 9 | kismayo
# Processing Record 2 of Set 9 | grindavik
# Processing Record 3 of Set 9 | aksha
# Processing Record 4 of Set 9 | valence
# Processing Record 5 of Set 9 | saldanha
# Processing Record 6 of Set 9 | kibala
# Processing Record 7 of Set 9 | chara
# Processing Record 8 of Set 9 | sibolga
# Processing Record 9 of Set 9 | victoria
# Processing Record 10 of Set 9 | athabasca
# Processing Record 11 of Set 9 | deputatskiy
# Processing Record 12 of Set 9 | chapais
# Processing Record 13 of Set 9 | san miguel
# Processing Record 14 of Set 9 | teknaf
# Processing Record 15 of Set 9 | huilong
# Processing Record 16 of Set 9 | kiyasovo
# Processing Record 17 of Set 9 | traralgon
# Processing Record 18 of Set 9 | russell
# Processing Record 19 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 9 | palmer
# Processing Record 21 of Set 9 | arcachon
# Processing Record 22 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 9 | kungalv
# Processing Record 24 of Set 9 | haines junction
# Processing Record 25 of Set 9 | basco
# Processing Record 26 of Set 9 | namibe
# Processing Record 27 of Set 9 | at-bashi
# Processing Record 28 of Set 9 | dingle
# Processing Record 29 of Set 9 | dhar
# Processing Record 30 of Set 9 | norman wells
# Processing Record 31 of Set 9 | carrollton
# Processing Record 32 of Set 9 | concarneau
# Processing Record 33 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 9 | paita
# Processing Record 35 of Set 9 | acopiara
# Processing Record 36 of Set 9 | vestmannaeyjar
# Processing Record 37 of Set 9 | nyurba
# Processing Record 38 of Set 9 | trincomalee
# Processing Record 39 of Set 9 | bolobo
# Processing Record 40 of Set 9 | doha
# Processing Record 41 of Set 9 | leticia
# Processing Record 42 of Set 9 | ust-maya
# Processing Record 43 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 9 | kharp
# Processing Record 45 of Set 9 | marsa matruh
# Processing Record 46 of Set 9 | presidente epitacio
# Processing Record 47 of Set 9 | mulanje
# Processing Record 48 of Set 9 | tromso
# Processing Record 49 of Set 9 | pacific grove
# Processing Record 50 of Set 9 | oistins
# Processing Record 1 of Set 10 | roald
# Processing Record 2 of Set 10 | kushima
# Processing Record 3 of Set 10 | pedra branca
# Processing Record 4 of Set 10 | smirnykh
# Processing Record 5 of Set 10 | tilichiki
# Processing Record 6 of Set 10 | naze
# Processing Record 7 of Set 10 | esperance
# Processing Record 8 of Set 10 | kashi
# Processing Record 9 of Set 10 | sao gabriel
# Processing Record 10 of Set 10 | alyangula
# Processing Record 11 of Set 10 | shu
# Processing Record 12 of Set 10 | christchurch
# Processing Record 13 of Set 10 | bilibino
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | wharton
# Processing Record 16 of Set 10 | ostersund
# Processing Record 17 of Set 10 | dana point
# Processing Record 18 of Set 10 | mayumba
# Processing Record 19 of Set 10 | shiroishi
# Processing Record 20 of Set 10 | senneterre
# Processing Record 21 of Set 10 | puerto madryn
# Processing Record 22 of Set 10 | monrovia
# Processing Record 23 of Set 10 | sainte-maxime
# Processing Record 24 of Set 10 | farafangana
# Processing Record 25 of Set 10 | lyantonde
# Processing Record 26 of Set 10 | khoy
# Processing Record 27 of Set 10 | hambantota
# Processing Record 28 of Set 10 | sola
# Processing Record 29 of Set 10 | thinadhoo
# Processing Record 30 of Set 10 | coffeyville
# Processing Record 31 of Set 10 | bozeman
# Processing Record 32 of Set 10 | bambanglipuro
# Processing Record 33 of Set 10 | san vicente
# Processing Record 34 of Set 10 | burnie
# Processing Record 35 of Set 10 | aybak
# City not found. Skipping...
# Processing Record 36 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | tahe
# Processing Record 38 of Set 10 | nishihara
# Processing Record 39 of Set 10 | simao
# Processing Record 40 of Set 10 | kindu
# Processing Record 41 of Set 10 | maniitsoq
# Processing Record 42 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | imbituba
# Processing Record 44 of Set 10 | paramonga
# Processing Record 45 of Set 10 | alamosa
# Processing Record 46 of Set 10 | salta
# Processing Record 47 of Set 10 | yumen
# Processing Record 48 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 10 | ciras
# City not found. Skipping...
# Processing Record 50 of Set 10 | bad ems
# Processing Record 1 of Set 11 | posadas
# Processing Record 2 of Set 11 | narsaq
# Processing Record 3 of Set 11 | mamallapuram
# Processing Record 4 of Set 11 | wewak
# Processing Record 5 of Set 11 | ye
# City not found. Skipping...
# Processing Record 6 of Set 11 | abu samrah
# Processing Record 7 of Set 11 | nizwa
# Processing Record 8 of Set 11 | jalu
# Processing Record 9 of Set 11 | tonj
# Processing Record 10 of Set 11 | farmington
# Processing Record 11 of Set 11 | algiers
# Processing Record 12 of Set 11 | nakatsu
# Processing Record 13 of Set 11 | aitape
# Processing Record 14 of Set 11 | sabha
# Processing Record 15 of Set 11 | general roca
# Processing Record 16 of Set 11 | cidreira
# Processing Record 17 of Set 11 | luderitz
# Processing Record 18 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 11 | hamina
# Processing Record 20 of Set 11 | tura
# Processing Record 21 of Set 11 | balkanabat
# Processing Record 22 of Set 11 | nemuro
# Processing Record 23 of Set 11 | bonavista
# Processing Record 24 of Set 11 | caravelas
# Processing Record 25 of Set 11 | galveston
# Processing Record 26 of Set 11 | kandhla
# Processing Record 27 of Set 11 | sorland
# Processing Record 28 of Set 11 | raga
# Processing Record 29 of Set 11 | dawson creek
# Processing Record 30 of Set 11 | miri
# Processing Record 31 of Set 11 | zhigansk
# Processing Record 32 of Set 11 | durban
# Processing Record 33 of Set 11 | lavrentiya
# Processing Record 34 of Set 11 | terrak
# Processing Record 35 of Set 11 | svetlogorsk
# Processing Record 36 of Set 11 | sattahip
# Processing Record 37 of Set 11 | karpogory
# Processing Record 38 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 11 | linhai
# Processing Record 40 of Set 11 | oksfjord
# Processing Record 41 of Set 11 | araguaina
# Processing Record 42 of Set 11 | villamontes
# Processing Record 43 of Set 11 | kiama
# Processing Record 44 of Set 11 | cabedelo
# Processing Record 45 of Set 11 | pekan
# Processing Record 46 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 11 | mayma
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | aykhal
# Processing Record 50 of Set 11 | tortoli
# Processing Record 1 of Set 12 | isiolo
# Processing Record 2 of Set 12 | bilma
# Processing Record 3 of Set 12 | mananjary
# Processing Record 4 of Set 12 | tanout
# Processing Record 5 of Set 12 | saint-augustin
# Processing Record 6 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 12 | nezhinka
# Processing Record 8 of Set 12 | beloha
# Processing Record 9 of Set 12 | shubarshi
# Processing Record 10 of Set 12 | aklavik
# Processing Record 11 of Set 12 | batagay
# Processing Record 12 of Set 12 | porkhov
# Processing Record 13 of Set 12 | suez
# Processing Record 14 of Set 12 | qiongshan
# Processing Record 15 of Set 12 | cuamba
# Processing Record 16 of Set 12 | rocha
# Processing Record 17 of Set 12 | leningradskiy
# Processing Record 18 of Set 12 | kalmunai
# Processing Record 19 of Set 12 | pangkalanbuun
# Processing Record 20 of Set 12 | plouzane
# Processing Record 21 of Set 12 | manggar
# Processing Record 22 of Set 12 | maloy
# Processing Record 23 of Set 12 | tabas
# Processing Record 24 of Set 12 | elat
# Processing Record 25 of Set 12 | camara de lobos
# Processing Record 26 of Set 12 | bay roberts
# Processing Record 27 of Set 12 | fuyu
# Processing Record 28 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 29 of Set 12 | volchikha
# Processing Record 30 of Set 12 | mapiripan
# Processing Record 31 of Set 12 | sabang
# Processing Record 32 of Set 12 | mumford
# Processing Record 33 of Set 12 | marmaris
# Processing Record 34 of Set 12 | tucuman
# Processing Record 35 of Set 12 | tombouctou
# Processing Record 36 of Set 12 | ekibastuz
# Processing Record 37 of Set 12 | flinders
# Processing Record 38 of Set 12 | blackwater
# Processing Record 39 of Set 12 | nelson bay
# Processing Record 40 of Set 12 | yangcun
# Processing Record 41 of Set 12 | estevan
# Processing Record 42 of Set 12 | mana
# Processing Record 43 of Set 12 | ondjiva
# Processing Record 44 of Set 12 | camacha
# Processing Record 45 of Set 12 | sheridan
# Processing Record 46 of Set 12 | wanning
# Processing Record 47 of Set 12 | yar-sale
# Processing Record 48 of Set 12 | blagoyevo
# Processing Record 49 of Set 12 | sao jose da coroa grande
# Processing Record 50 of Set 12 | domoni
# Processing Record 1 of Set 13 | fairbanks
# Processing Record 2 of Set 13 | evensk
# Processing Record 3 of Set 13 | breytovo
# Processing Record 4 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 5 of Set 13 | bafq
# Processing Record 6 of Set 13 | westerland
# Processing Record 7 of Set 13 | yerbogachen
# Processing Record 8 of Set 13 | vallenar
# Processing Record 9 of Set 13 | khandyga
# Processing Record 10 of Set 13 | namatanai
# Processing Record 11 of Set 13 | tongchuan
# Processing Record 12 of Set 13 | shieli
# Processing Record 13 of Set 13 | ha giang
# Processing Record 14 of Set 13 | ulaanbaatar
# Processing Record 15 of Set 13 | miles city
# Processing Record 16 of Set 13 | wuwei
# Processing Record 17 of Set 13 | baharampur
# Processing Record 18 of Set 13 | nurota
# Processing Record 19 of Set 13 | skelleftea
# Processing Record 20 of Set 13 | coihaique
# Processing Record 21 of Set 13 | komsomolskiy
# Processing Record 22 of Set 13 | nuuk
# Processing Record 23 of Set 13 | sidney
# Processing Record 24 of Set 13 | varhaug
# Processing Record 25 of Set 13 | chicama
# Processing Record 26 of Set 13 | yanai
# Processing Record 27 of Set 13 | nashville
# Processing Record 28 of Set 13 | jawa
# Processing Record 29 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 13 | thunder bay
# Processing Record 31 of Set 13 | severo-yeniseyskiy
# Processing Record 32 of Set 13 | riyadh
# Processing Record 33 of Set 13 | araouane
# Processing Record 34 of Set 13 | dabakala
# Processing Record 35 of Set 13 | pouembout
# Processing Record 36 of Set 13 | mandla
# Processing Record 37 of Set 13 | antalaha
# Processing Record 38 of Set 13 | morondava
# Processing Record 39 of Set 13 | kralendijk
# Processing Record 40 of Set 13 | dodge city
# Processing Record 41 of Set 13 | port hawkesbury
# Processing Record 42 of Set 13 | juba
# Processing Record 43 of Set 13 | markova
# Processing Record 44 of Set 13 | eatonton
# Processing Record 45 of Set 13 | mosina
# Processing Record 46 of Set 13 | hudson bay
# Processing Record 47 of Set 13 | ntcheu
# Processing Record 48 of Set 13 | huangpi
# Processing Record 49 of Set 13 | berdigestyakh
# Processing Record 50 of Set 13 | quesnel
# Processing Record 1 of Set 14 | gazli
# Processing Record 2 of Set 14 | mpongwe
# Processing Record 3 of Set 14 | bull savanna
# Processing Record 4 of Set 14 | dutlwe
# Processing Record 5 of Set 14 | taitung
# Processing Record 6 of Set 14 | chesma
# Processing Record 7 of Set 14 | sandakan
# Processing Record 8 of Set 14 | qui nhon
# Processing Record 9 of Set 14 | acari
# Processing Record 10 of Set 14 | bontang
# Processing Record 11 of Set 14 | phu ly
# Processing Record 12 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 13 of Set 14 | solnechnyy
# Processing Record 14 of Set 14 | raudeberg
# Processing Record 15 of Set 14 | novaya bryan
# Processing Record 16 of Set 14 | lodja
# Processing Record 17 of Set 14 | borogontsy
# Processing Record 18 of Set 14 | guerrero negro
# Processing Record 19 of Set 14 | lata
# Processing Record 20 of Set 14 | port hedland
# Processing Record 21 of Set 14 | la ronge
# Processing Record 22 of Set 14 | tongzi
# Processing Record 23 of Set 14 | herat
# Processing Record 24 of Set 14 | broken hill
# Processing Record 25 of Set 14 | alta floresta
# Processing Record 26 of Set 14 | weihai
# Processing Record 27 of Set 14 | berlevag
# Processing Record 28 of Set 14 | nikolsk
# Processing Record 29 of Set 14 | paamiut
# Processing Record 30 of Set 14 | guilin
# Processing Record 31 of Set 14 | hanmer springs
# Processing Record 32 of Set 14 | nantucket
# Processing Record 33 of Set 14 | tambura
# Processing Record 34 of Set 14 | sosnovo-ozerskoye
# Processing Record 35 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 14 | yangambi
# Processing Record 37 of Set 14 | lerik
# Processing Record 38 of Set 14 | great yarmouth
# Processing Record 39 of Set 14 | half moon bay
# Processing Record 40 of Set 14 | manta
# Processing Record 41 of Set 14 | srednekolymsk
# Processing Record 42 of Set 14 | tawala
# Processing Record 43 of Set 14 | solano
# Processing Record 44 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 45 of Set 14 | prince rupert
# Processing Record 46 of Set 14 | kurilsk
# Processing Record 47 of Set 14 | senanga
# Processing Record 48 of Set 14 | husavik
# Processing Record 49 of Set 14 | lidzbark warminski
# Processing Record 50 of Set 14 | sibu
# Processing Record 1 of Set 15 | antsirabe
# Processing Record 2 of Set 15 | pirapozinho
# Processing Record 3 of Set 15 | puerto escondido
# Processing Record 4 of Set 15 | marfino
# Processing Record 5 of Set 15 | bathsheba
# Processing Record 6 of Set 15 | atmakur
# Processing Record 7 of Set 15 | kieta
# Processing Record 8 of Set 15 | kaminskiy
# Processing Record 9 of Set 15 | taltal
# Processing Record 10 of Set 15 | norheimsund
# Processing Record 11 of Set 15 | parana
# Processing Record 12 of Set 15 | vilcun
# Processing Record 13 of Set 15 | shipunovo
# Processing Record 14 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 15 | saint-marc
# Processing Record 16 of Set 15 | sonderso
# Processing Record 17 of Set 15 | tefe
# Processing Record 18 of Set 15 | tautira
# Processing Record 19 of Set 15 | naryan-mar
# Processing Record 20 of Set 15 | ambagarh chauki
# Processing Record 21 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 15 | dunkwa
# Processing Record 23 of Set 15 | ust-nera
# Processing Record 24 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 15 | harper
# Processing Record 26 of Set 15 | goianesia
# Processing Record 27 of Set 15 | echternach
# Processing Record 28 of Set 15 | tambun
# Processing Record 29 of Set 15 | mixtepec
# City not found. Skipping...
# Processing Record 30 of Set 15 | okitipupa
# Processing Record 31 of Set 15 | quelimane
# Processing Record 32 of Set 15 | lewistown
# Processing Record 33 of Set 15 | buriti bravo
# Processing Record 34 of Set 15 | the valley
# Processing Record 35 of Set 15 | yalta
# Processing Record 36 of Set 15 | pangnirtung
# Processing Record 37 of Set 15 | hagersville
# Processing Record 38 of Set 15 | zion
# Processing Record 39 of Set 15 | fuyang
# Processing Record 40 of Set 15 | beroroha
# Processing Record 41 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 15 | miguel hidalgo
# Processing Record 43 of Set 15 | palaikastron
# Processing Record 44 of Set 15 | villarrica
# Processing Record 45 of Set 15 | banda
# Processing Record 46 of Set 15 | sal rei
# Processing Record 47 of Set 15 | daytona beach
# Processing Record 48 of Set 15 | hualmay
# Processing Record 49 of Set 15 | itarema
# Processing Record 50 of Set 15 | uvira
# Processing Record 1 of Set 16 | katangli
# Processing Record 2 of Set 16 | bonthe
# Processing Record 3 of Set 16 | road town
# Processing Record 4 of Set 16 | katsuura
# Processing Record 5 of Set 16 | dryden
# Processing Record 6 of Set 16 | vredendal
# Processing Record 7 of Set 16 | vila
# Processing Record 8 of Set 16 | kushiro
# Processing Record 9 of Set 16 | salalah
# Processing Record 10 of Set 16 | rapar
# Processing Record 11 of Set 16 | morant bay
# Processing Record 12 of Set 16 | laranjeiras do sul
# Processing Record 13 of Set 16 | jumla
# Processing Record 14 of Set 16 | shache
# Processing Record 15 of Set 16 | zima
# Processing Record 16 of Set 16 | pathein
# Processing Record 17 of Set 16 | japura
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mataura -46.1927  168.8643     35.47        84         100        2.44
# 1       Hobart -42.8794  147.3294     48.06        70          40        1.99
# 2         Auki  -8.7676  160.7034     74.16        87           5        4.43
# 3      Sambava -14.2667   50.1667     69.66        80           0       12.01
# 4      Namwala -15.7504   26.4384     65.32        30           0        6.35
# 5      Ushuaia -54.8000  -68.3000     53.26        47          75       16.11
# 6  New Norfolk -42.7826  147.0587     47.71        68          99        1.01
# 7    Busselton -33.6500  115.3333     48.04        90           1        6.22
# 8      Cayenne   4.9333  -52.3333     85.08        71          75        3.44
# 9         Hilo  19.7297 -155.0900     74.80        87          90        5.75
#
#   Country Current Description
# 0      NZ     overcast clouds
# 1      AU    scattered clouds
# 2      SB           clear sky
# 3      MG           clear sky
# 4      ZM           clear sky
# 5      AR       broken clouds
# 6      AU     overcast clouds
# 7      AU           clear sky
# 8      GF       broken clouds
# 9      US          light rain

# %%
# Change the column order
new_column_order  = ['City','Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Assign district summary df the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mataura      NZ -46.1927  168.8643     35.47        84         100
# 1       Hobart      AU -42.8794  147.3294     48.06        70          40
# 2         Auki      SB  -8.7676  160.7034     74.16        87           5
# 3      Sambava      MG -14.2667   50.1667     69.66        80           0
# 4      Namwala      ZM -15.7504   26.4384     65.32        30           0
# 5      Ushuaia      AR -54.8000  -68.3000     53.26        47          75
# 6  New Norfolk      AU -42.7826  147.0587     47.71        68          99
# 7    Busselton      AU -33.6500  115.3333     48.04        90           1
# 8      Cayenne      GF   4.9333  -52.3333     85.08        71          75
# 9         Hilo      US  19.7297 -155.0900     74.80        87          90
#
#    Wind Speed Current Description
# 0        2.44     overcast clouds
# 1        1.99    scattered clouds
# 2        4.43           clear sky
# 3       12.01           clear sky
# 4        6.35           clear sky
# 5       16.11       broken clouds
# 6        1.01     overcast clouds
# 7        6.22           clear sky
# 8        3.44       broken clouds
# 9        5.75          light rain

# %%
#Save dataframe as csv
pd.DataFrame.to_csv(city_data_df, 'WeatherPy_Database.csv',)
city_data_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mataura      NZ -46.1927  168.8643     35.47        84         100
# 1   Hobart      AU -42.8794  147.3294     48.06        70          40
# 2     Auki      SB  -8.7676  160.7034     74.16        87           5
# 3  Sambava      MG -14.2667   50.1667     69.66        80           0
# 4  Namwala      ZM -15.7504   26.4384     65.32        30           0
#
#    Wind Speed Current Description
# 0        2.44     overcast clouds
# 1        1.99    scattered clouds
# 2        4.43           clear sky
# 3       12.01           clear sky
# 4        6.35           clear sky
